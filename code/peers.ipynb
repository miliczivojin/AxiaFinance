# %%
import pandas as pd

from pathlib import Path

# %%
stocks = pd.read_csv(Path.cwd().parent / "data" / "stocks.csv")
stocks
# Out:
#       Symbol      marketcap        country                  sector  \
# 0       NVDA  5009871732736  United States              Technology
# 1       AAPL  4891182891008  United States              Technology
# 2       GOOG  3902449909760  United States  Communication Services
# 3       MSFT  2835433652224  United States              Technology
# 4       AMZN  2496832733184  United States       Consumer Cyclical
# ...      ...            ...            ...                     ...
# 3505    GDRX     1002479104  United States              Healthcare
# 3506    TRST     1002180416  United States      Financial Services
# 3507  8218.T     1001800523          Japan       Consumer Cyclical
# 3508    FSBC     1000617728  United States      Financial Services
# 3509     RXT     1000399936  United States              Technology
#
#                             industry  \
# 0                     Semiconductors
# 1               Consumer Electronics
# 2     Internet Content & Information
# ...
